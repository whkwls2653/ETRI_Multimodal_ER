# %% [markdown]
# <a href="https://colab.research.google.com/github/whkwls2653/ETRI_Multimodal_ER/blob/main/%EC%82%AC%EC%9A%A9%EB%B0%A9%EB%B2%95%EB%B0%8F_%EB%A6%AC%EB%8D%94%EB%B3%B4%EB%93%9C(2%EC%B0%A8%EA%B0%80%EC%82%B0%EC%A0%90).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER/
# Out:
# /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers (from -r requirements.txt (line 1))
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 52.8 MB/s eta 0:00:00
# Collecting pytorch-lightning (from -r requirements.txt (line 2))
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 47.6 MB/s eta 0:00:00
# Collecting torch-geometric (from -r requirements.txt (line 3))
#   Downloading torch_geometric-2.3.1.tar.gz (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 54.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting comet (from -r requirements.txt (line 4))
#   Downloading Comet-3.1.0.tar.gz (35 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (0.10.0.post2)
# Collecting sklearn (from -r requirements.txt (line 7))
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence_transformers (from -r requirements.txt (line 8))
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r requirements.txt (line 1))
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 1))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 118.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->-r requirements.txt (line 2)) (2.0.1+cu118)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->-r requirements.txt (line 2)) (2023.4.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->-r requirements.txt (line 2))
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->-r requirements.txt (line 2)) (4.5.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning->-r requirements.txt (line 2))
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric->-r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric->-r requirements.txt (line 3)) (5.9.5)
# Collecting twisted>=16.0.0 (from comet->-r requirements.txt (line 4))
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 100.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=2.3 in /usr/local/lib/python3.10/dist-packages (from comet->-r requirements.txt (line 4)) (4.9.2)
# Collecting zope.interface>=4.1.1 (from comet->-r requirements.txt (line 4))
#   Downloading zope.interface-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 28.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 8)) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers->-r requirements.txt (line 8)) (3.8.1)
# Collecting sentencepiece (from sentence_transformers->-r requirements.txt (line 8))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.4 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 81.3 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 6)) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 6)) (67.7.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa->-r requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (16.0.5)
# Collecting constantly>=15.1 (from twisted>=16.0.0->comet->-r requirements.txt (line 4))
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Collecting incremental>=21.3.0 (from twisted>=16.0.0->comet->-r requirements.txt (line 4))
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from twisted>=16.0.0->comet->-r requirements.txt (line 4))
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from twisted>=16.0.0->comet->-r requirements.txt (line 4))
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from twisted>=16.0.0->comet->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers->-r requirements.txt (line 8)) (8.4.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.7 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->-r requirements.txt (line 2))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r requirements.txt (line 6)) (2.21)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch-lightning->-r requirements.txt (line 2)) (1.3.0)
# Building wheels for collected packages: torch-geometric, comet, sklearn, sentence_transformers
#   Building wheel for torch-geometric (pyproject.toml) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=7732646a5d3484d7d3c401d8f3e30d9bc51d54997ae88f6d5443fd88777e0ea3
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
#   Building wheel for comet (setup.py) ... done
#   Created wheel for comet: filename=Comet-3.1.0-py3-none-any.whl size=57649 sha256=9dae257732b43b61af18ea21d83c3878b06cfb609a64b35ed39ec197b19082b8
#   Stored in directory: /root/.cache/pip/wheels/22/11/88/ae23a28c64e6e4edbac2dee344a54885a052b51b19925f1aa2
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2950 sha256=1a57808d00aeacbcfa39a76debff8e432e9069611bf402f7c675108e2dc8854e
#   Stored in directory: /root/.cache/pip/wheels/38/1f/8d/4f812c590e074c1e928f5cec67bf5053b71f38e2648739403a
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=047cb20c12a58246170471b74b4a51bd620a9b0aa20b15747273489374e026f5
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built torch-geometric comet sklearn sentence_transformers
# Installing collected packages: tokenizers, sklearn, sentencepiece, incremental, constantly, zope.interface, multidict, lightning-utilities, hyperlink, frozenlist, Automat, async-timeout, yarl, twisted, huggingface-hub, aiosignal, transformers, torch-geometric, comet, aiohttp, torchmetrics, sentence_transformers, pytorch-lightning
# Successfully installed Automat-22.10.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 comet-3.1.0 constantly-15.1.0 frozenlist-1.3.3 huggingface-hub-0.14.1 hyperlink-21.0.0 incremental-22.10.0 lightning-utilities-0.8.0 multidict-6.0.4 pytorch-lightning-2.0.2 sentence_transformers-2.2.2 sentencepiece-0.1.99 sklearn-0.0.post5 tokenizers-0.13.3 torch-geometric-2.3.1 torchmetrics-0.11.4 transformers-4.29.2 twisted-22.10.0 yarl-1.9.2 zope.interface-6.0

# %%
# !apt-get install p7zip
# %cd COGMEN_code
!7z x kernel.7z.001 -aoa
# %cd data
!7z x kernel.7z.001 -aoa
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip is already the newest version (16.02+dfsg-7build1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER/COGMEN_code
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 20971520 bytes (20 MiB)
#
# Extracting archive: kernel.7z.001
# --
# Path = kernel.7z.001
# Type = Split
# Physical Size = 20971520
# Volumes = 10
# Total Physical Size = 197565913
# ----
# Path = kernel.7z
# Size = 197565913
# --
# Path = kernel.7z
# Type = 7z
# Physical Size = 197565913
# Headers Size = 321
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 4
# Size:       218741600
# Compressed: 197565913
# /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER/COGMEN_code/data
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 20971520 bytes (20 MiB)
#
# Extracting archive: kernel.7z.001
# --
# Path = kernel.7z.001
# Type = Split
# Physical Size = 20971520
# Volumes = 6
# Total Physical Size = 125756776
# ----
# Path = kernel.7z
# Size = 125756776
# --
# Path = kernel.7z
# Type = 7z
# Physical Size = 125756776
# Headers Size = 332
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 2
# Files: 4
# Size:       152309495
# Compressed: 125756776

# %%
# %cd /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER/COGMEN_code
# !python eval.py --dataset="KEMDy19" --modalities="at" --data_dir='./data/KEMDy19/new_2019cogmen_format_speaker_only_feat_preprocessed.pkl' --pt_dir='./model_checkpoints/KEMDy19_best_dev_f1_model_at_MIRAI_pretrained_speaker_only.pt'
# Out:
# /content/gdrive/MyDrive/emotion_recognition/ETRI_Multimodal_ER/COGMEN_code
# Downloading (…)7f4ef/.gitattributes: 100% 391/391 [00:00<00:00, 2.68MB/s]
# Downloading (…)_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.16MB/s]
# Downloading (…)f279f7f4ef/README.md: 100% 3.74k/3.74k [00:00<00:00, 25.1MB/s]
# Downloading (…)79f7f4ef/config.json: 100% 718/718 [00:00<00:00, 5.44MB/s]
# Downloading (…)ce_transformers.json: 100% 122/122 [00:00<00:00, 937kB/s]
# Downloading (…)279f7f4ef/merges.txt: 100% 456k/456k [00:00<00:00, 6.32MB/s]
# Downloading pytorch_model.bin: 100% 329M/329M [00:01<00:00, 219MB/s]
# Downloading (…)nce_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 320kB/s]
# Downloading (…)cial_tokens_map.json: 100% 239/239 [00:00<00:00, 1.19MB/s]
# Downloading (…)7f4ef/tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 11.3MB/s]
# Downloading (…)okenizer_config.json: 100% 1.35k/1.35k [00:00<00:00, 8.09MB/s]
# Downloading (…)279f7f4ef/vocab.json: 100% 798k/798k [00:00<00:00, 11.3MB/s]
# Downloading (…)9f7f4ef/modules.json: 100% 229/229 [00:00<00:00, 1.19MB/s]
# test: 100% 1/1 [00:03<00:00,  3.59s/it]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0     0.7126    0.8547    0.7772       351
#            1     0.6638    0.7685    0.7123       203
#            2     0.8981    0.6258    0.7376       155
#            3     0.7922    0.6162    0.6932        99
#            4     0.7449    0.9605    0.8391        76
#            5     0.5641    0.8148    0.6667        27
#            6     0.0000    0.0000    0.0000        67
#
#     accuracy                         0.7249       978
#    macro avg     0.6251    0.6629    0.6323       978
# weighted avg     0.6895    0.7249    0.6975       978
#
# F1 Score: 0.6974748291310351
